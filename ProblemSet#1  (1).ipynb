# %%
import pandas as pd

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_excel("problemset1.xlsx")

# %%
df.columns
# Out:
# Index(['Пол', 'Возраст', 'Семейное положение', 'Национальность',
#        'Повторный клиент', 'Сумма выдачи номинал', 'Дата выдачи',
#        'Дата окончание срока', 'Валюта', 'Срок', 'Тип залога', 'Образование',
#        'Тип бизнеса', 'Цель кредита', 'Просрочки за цикл (кумулятивный)',
#        'Длительность самой долгой единовременной просрочки в течение цикла',
#        'Просрочки на дату 07.06.2021', 'Льготный период', 'Дата списания',
#        'Сумма списания'],
#       dtype='object')

# %%
df
# Out:
#        Пол     Возраст Семейное положение Национальность Повторный клиент  \
# 0      Муж  05.07.1985            Married         Таджик    Старый клиент
# 1      Муж  05.07.1985            Married         Таджик    Старый клиент
# 2      Муж  05.07.1985            Married         Таджик    Старый клиент
# 3      Жен  00.00.0000                NaN            NaN    Старый клиент
# 4      Жен  00.00.0000                NaN            NaN    Старый клиент
# ...    ...         ...                ...            ...              ...
# 14148  Муж  10.06.1997             Single         Таджик    Старый клиент
# 14149  Жен  06.10.1993             Single         Таджик    Старый клиент
# 14150  Муж  15.06.1994            Married         Таджик    Старый клиент
# 14151  Муж  27.10.1971            Married         Таджик    Старый клиент
# 14152  Жен  10.01.1979           Divorced         Таджик    Старый клиент
#
#        Сумма выдачи номинал Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
df.head(30)
# Out:
#     Пол     Возраст Семейное положение Национальность Повторный клиент  \
# 0   Муж  05.07.1985            Married         Таджик    Старый клиент
# 1   Муж  05.07.1985            Married         Таджик    Старый клиент
# 2   Муж  05.07.1985            Married         Таджик    Старый клиент
# 3   Жен  00.00.0000                NaN            NaN    Старый клиент
# 4   Жен  00.00.0000                NaN            NaN    Старый клиент
# 5   Жен  00.00.0000                NaN            NaN    Старый клиент
# 6   Жен  00.00.0000                NaN            NaN    Старый клиент
# 7   Муж  28.05.1990            Married         Таджик    Старый клиент
# 8   Муж  28.05.1990            Married         Таджик    Старый клиент
# 9   Муж  28.05.1990            Married         Таджик    Старый клиент
# 10  Муж  28.05.1990            Married         Таджик    Старый клиент
# 11  Муж  28.05.1990            Married         Таджик    Старый клиент
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13795 non-null  object
#  3   Национальность                                                      14140 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Пол', 'Возраст', 'Семейное положение', 'Национальность',
#        'Повторный клиент', 'Сумма выдачи номинал', 'Дата выдачи',
#        'Дата окончание срока', 'Валюта', 'Срок', 'Тип залога', 'Образование',
#        'Тип бизнеса', 'Цель кредита', 'Просрочки за цикл (кумулятивный)',
#        'Длительность самой долгой единовременной просрочки в течение цикла',
#        'Просрочки на дату 07.06.2021', 'Льготный период', 'Дата списания',
#        'Сумма списания'],
#       dtype='object')

# %%
missing_indices = df[df['Семейное положение'].isnull()].index
missing_indices
# Out:
# Int64Index([    3,     4,     5,     6,    63,    64,    65,    66,    67,
#                68,
#             ...
#             13550, 13570, 13619, 13652, 13657, 13703, 13733, 13848, 13862,
#             14097],
#            dtype='int64', length=358)

# %%
values_to_insert = 'Married'
missing_indicies = df[df['Семейное положение'].isnull()].index 
for index in missing_indicies[:160]:
    df.at[index, 'Семейное положение'] = values_to_insert
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13955 non-null  object
#  3   Национальность                                                      14140 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
Value_to_insert = 'Divorced'
missing_indicies = df[df['Семейное положение'].isnull()].index
for index in missing_indicies[161:281]:
    df.at[index,'Семейное положение'] = Value_to_insert

# %%
df.head(240)
# Out:
#      Пол     Возраст Семейное положение Национальность Повторный клиент  \
# 0    Муж  05.07.1985            Married         Таджик    Старый клиент
# 1    Муж  05.07.1985            Married         Таджик    Старый клиент
# 2    Муж  05.07.1985            Married         Таджик    Старый клиент
# 3    Жен  00.00.0000            Married            NaN    Старый клиент
# 4    Жен  00.00.0000            Married            NaN    Старый клиент
# ..   ...         ...                ...            ...              ...
# 235  Жен  18.02.1972           Divorced         Таджик    Старый клиент
# 236  Жен  16.03.1982           Divorced         Таджик    Старый клиент
# 237  Муж  24.10.1977            Married         Таджик    Старый клиент
# 238  Муж  20.05.1987            Married         Таджик    Старый клиент
# 239  Жен  17.06.1965            Married         Таджик    Старый клиент
#
#      Сумма выдачи номинал Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
vti = 'Widow/Widower'
mind = df[df['Семейное положение'].isnull()].index
for i in mind[281:402]:
    df.at[i, 'Семейное положение'] = vti

# %%
df
# Out:
#        Пол     Возраст Семейное положение Национальность Повторный клиент  \
# 0      Муж  05.07.1985            Married         Таджик    Старый клиент
# 1      Муж  05.07.1985            Married         Таджик    Старый клиент
# 2      Муж  05.07.1985            Married         Таджик    Старый клиент
# 3      Жен  00.00.0000            Married            NaN    Старый клиент
# 4      Жен  00.00.0000            Married            NaN    Старый клиент
# ...    ...         ...                ...            ...              ...
# 14148  Муж  10.06.1997             Single         Таджик    Старый клиент
# 14149  Жен  06.10.1993             Single         Таджик    Старый клиент
# 14150  Муж  15.06.1994            Married         Таджик    Старый клиент
# 14151  Муж  27.10.1971            Married         Таджик    Старый клиент
# 14152  Жен  10.01.1979           Divorced         Таджик    Старый клиент
#
#        Сумма выдачи номинал Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14140 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
df.describe()
# Out:
#        Сумма выдачи номинал          Срок  Просрочки за цикл (кумулятивный)  \
# count          14153.000000  14153.000000                      14153.000000
# mean            9372.064409     15.666219                         28.192892
# std            14533.973249      5.525541                         89.833741
# min              900.000000      0.000000                          0.000000
# 25%             5000.000000     12.000000                          0.000000
# 50%             6000.000000     12.000000                          1.000000
# 75%            10000.000000     18.000000                         12.000000
# max           500000.000000    120.000000                       1749.000000
#
#        Длительность самой долгой единовременной просрочки в течение цикла  \
# count                                       14153.000000
# mean                                           15.553876
# std                                            63.455929
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14140 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Таджик'
minds = df[df['Национальность'].isnull()].index
for i in minds[:13]:
    df.at[i, 'Национальность'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
df['Образование'].unique()
# Out:
# array(['Высшее образование', nan, 'Среднее образование',
#        'Сред.спец.образ-ние', 'Непол Сред.образ', 'Аспирантура',
#        'Начал образование'], dtype=object)

# %%
vti = 'Высшее образование'
mind = df[df['Образование'].isnull()].index
for i in mind[:71]:
    df.at[i, 'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Непол Сред.образ'
mind = df[df['Образование'].isnull()].index
for i in mind[72:100]:
    df.at[i,'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Среднее образование'

for i in mind[101:160]:
    df.at[i, 'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Сред.спец.образ-ние'

for i in mind[161:221]:
    df.at[i, 'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Аспирантура'
mind = df[df['Образование'].isnull()].index
for i in mind[:37]:
    df.at[i, 'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
vti = 'Начал образование'
mind = df[df['Образование'].isnull()].index
for i in mind[:36]:
    df.at[i, 'Образование'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
df['Цель кредита'].unique()
# Out:
# array(['Оборотный капитал', 'Основные средства', 'Потребительские цели',
#        'Ремонт жилья', 'Строительство жилья',
#        'Баланд бардоштани сам. эн. манзил', 'Покупка жилья', 'Старт-ап',
#        nan], dtype=object)

# %%
vti = 'Оборотный капитал'
mind = df[df['Цель кредита'].isnull()].index
for i in mind[:1]:
    df.at[i, 'Цель кредита'] = vti
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  object
#  2   Семейное положение                                                  13992 non-null  object
#  3   Национальность                                                      14153 non-null  object
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
data = df 
data
# Out:
#        Пол     Возраст Семейное положение Национальность Повторный клиент  \
# 0      Муж  05.07.1985            Married         Таджик    Старый клиент
# 1      Муж  05.07.1985            Married         Таджик    Старый клиент
# 2      Муж  05.07.1985            Married         Таджик    Старый клиент
# 3      Жен  00.00.0000            Married         Таджик    Старый клиент
# 4      Жен  00.00.0000            Married         Таджик    Старый клиент
# ...    ...         ...                ...            ...              ...
# 14148  Муж  10.06.1997             Single         Таджик    Старый клиент
# 14149  Жен  06.10.1993             Single         Таджик    Старый клиент
# 14150  Муж  15.06.1994            Married         Таджик    Старый клиент
# 14151  Муж  27.10.1971            Married         Таджик    Старый клиент
# 14152  Жен  10.01.1979           Divorced         Таджик    Старый клиент
#
#        Сумма выдачи номинал Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['Семейное положение'] = le.fit_transform(data['Семейное положение'])

# %%
data['Семейное положение'].unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
df['Семейное положение'].unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
df
# Out:
#        Пол     Возраст  Семейное положение Национальность Повторный клиент  \
# 0      Муж  05.07.1985                   1         Таджик    Старый клиент
# 1      Муж  05.07.1985                   1         Таджик    Старый клиент
# 2      Муж  05.07.1985                   1         Таджик    Старый клиент
# 3      Жен  00.00.0000                   1         Таджик    Старый клиент
# 4      Жен  00.00.0000                   1         Таджик    Старый клиент
# ...    ...         ...                 ...            ...              ...
# 14148  Муж  10.06.1997                   2         Таджик    Старый клиент
# 14149  Жен  06.10.1993                   2         Таджик    Старый клиент
# 14150  Муж  15.06.1994                   1         Таджик    Старый клиент
# 14151  Муж  27.10.1971                   1         Таджик    Старый клиент
# 14152  Жен  10.01.1979                   0         Таджик    Старый клиент
#
# ...

# %%
data['Национальность'].unique()
# Out:
# array(['Таджик', 'Узбек', 'точик', 'осатин', 'Другие', 'Русский', 'Уйгур',
#        'Озарбойчон', 'уйгур', 'Татар', 'Точик', 'Гурчи', 'Авгон', 'Немка',
#        'туркман', 'циган'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Национальность'] = le.fit_transform(df['Национальность'])

# %%
df['Национальность'].unique()
# Out:
# array([ 6,  9, 12, 11,  2,  5, 10,  4, 14,  7,  8,  1,  0,  3, 13, 15])

# %%
df['Возраст'].unique()
# Out:
# array(['05.07.1985', '00.00.0000', '28.05.1990', ..., '23.10.1993',
#        '09.12.2000', '27.10.1971'], dtype=object)

# %%
n=0
for i in range(0,14153):
    if (df.at[i, 'Возраст'] == '00.00.0000'):
        df.at[i, 'Возраст'] = float('nan')
        print(df.at[i, 'Возраст'])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
df['Возраст'] = pd.to_datetime(df['Возраст'], format = '%d.%m.%Y')
df['Возраст'] = df['Возраст'].dt.year

# %%
df['Возраст'] = df['Возраст'].fillna(df['Возраст'].mean())

# %%
df['Возраст'].unique()
# Out:
# array([1985.        , 1982.58521924, 1990.        , 1994.        ,
#        1974.        , 1968.        , 1988.        , 1967.        ,
#        1971.        , 1963.        , 1962.        , 1986.        ,
#        1969.        , 1966.        , 1992.        , 1997.        ,
#        1976.        , 1977.        , 1993.        , 1980.        ,
#        1975.        , 1996.        , 1972.        , 1987.        ,
#        1970.        , 1989.        , 1965.        , 1991.        ,
#        1960.        , 1984.        , 1995.        , 1983.        ,
#        1978.        , 1973.        , 1979.        , 1982.        ,
#        1964.        , 1999.        , 1958.        , 1956.        ,
#        1998.        , 1957.        , 1959.        , 1981.        ,
#        1961.        , 1948.        , 1955.        , 1953.        ,
#        1954.        , 2000.        , 1951.        , 1952.        ,
#        2001.        , 1950.        , 1943.        , 2002.        ])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14153 entries, 0 to 14152
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Пол                                                                 14153 non-null  object
#  1   Возраст                                                             14153 non-null  float64
#  2   Семейное положение                                                  14153 non-null  int32
#  3   Национальность                                                      14153 non-null  int32
#  4   Повторный клиент                                                    14153 non-null  object
#  5   Сумма выдачи номинал                                                14153 non-null  float64
#  6   Дата выдачи                                                         14153 non-null  object
# ...

# %%
df['Возраст'].unique()
# Out:
# array([1985.        , 1982.58521924, 1990.        , 1994.        ,
#        1974.        , 1968.        , 1988.        , 1967.        ,
#        1971.        , 1963.        , 1962.        , 1986.        ,
#        1969.        , 1966.        , 1992.        , 1997.        ,
#        1976.        , 1977.        , 1993.        , 1980.        ,
#        1975.        , 1996.        , 1972.        , 1987.        ,
#        1970.        , 1989.        , 1965.        , 1991.        ,
#        1960.        , 1984.        , 1995.        , 1983.        ,
#        1978.        , 1973.        , 1979.        , 1982.        ,
#        1964.        , 1999.        , 1958.        , 1956.        ,
#        1998.        , 1957.        , 1959.        , 1981.        ,
#        1961.        , 1948.        , 1955.        , 1953.        ,
#        1954.        , 2000.        , 1951.        , 1952.        ,
#        2001.        , 1950.        , 1943.        , 2002.        ])

# %%
df['Возраст'] = df['Возраст'].astype(int)

# %%
df['Возраст']
# Out:
# 0        1985
# 1        1985
# 2        1985
# 3        1982
# 4        1982
#          ...
# 14148    1997
# 14149    1993
# 14150    1994
# 14151    1971
# 14152    1979
# Name: Возраст, Length: 14153, dtype: int32

# %%
df['Дата выдачи'].unique()
# Out:
# array(['25.12.2019', '04.02.2015', '23.12.2016', '08.05.2015',
#        '26.05.2016', '20.03.2017', '17.07.2019', '31.12.2019',
#        '21.05.2015', '24.05.2017', '18.01.2018', '17.02.2021',
#        '15.01.2020', '16.07.2015', '31.10.2018', '19.03.2021',
#        '27.11.2015', '31.03.2017', '29.03.2019', '28.03.2018',
#        '16.12.2015', '18.08.2017', '12.04.2019', '25.06.2016',
#        '24.06.2017', '15.07.2020', '22.09.2016', '13.09.2018',
#        '22.02.2021', '10.11.2016', '21.11.2018', '17.01.2020',
#        '22.12.2016', '07.12.2017', '13.01.2017', '27.09.2017',
#        '21.09.2018', '30.11.2017', '28.02.2017', '20.09.2018',
#        '14.06.2019', '07.09.2018', '29.08.2017', '25.01.2019',
#        '30.06.2017', '18.09.2018', '01.06.2018', '05.06.2018',
#        '06.06.2018', '04.06.2018', '25.07.2018', '05.09.2018',
#        '23.11.2018', '25.10.2018', '22.02.2019', '26.12.2018',
#        '20.03.2019', '02.05.2019', '07.06.2018', '08.06.2018',
# ...

# %%
df['Дата выдачи'] = pd.to_datetime(df['Дата выдачи'], format = '%d.%m.%Y')
df['Дата выдачи'] = df['Дата выдачи'].dt.year
df['Дата выдачи'] = df['Дата выдачи'].astype(int)
df['Дата выдачи'].unique()
# Out:
# array([2019, 2015, 2016, 2017, 2018, 2021, 2020])

# %%
df['Возраст'] = df['Дата выдачи'] - df['Возраст']
df['Возраст'].unique()
# Out:
# array([34, 30, 31, 33, 35, 37, 29, 25, 27, 28, 26, 21, 24, 41, 43, 45, 50,
#        47, 49, 51, 32, 54, 46, 42, 55, 56, 44, 57, 23, 52, 38, 36, 22, 48,
#        53, 58, 40, 39, 19, 60, 62, 20, 61, 59, 70, 63, 65, 64, 18, 67, 66,
#        68, 69, 71, 76, 72, 73])

# %%
df
# Out:
#        Пол  Возраст  Семейное положение  Национальность Повторный клиент  \
# 0      Муж       34                   1               6    Старый клиент
# 1      Муж       30                   1               6    Старый клиент
# 2      Муж       31                   1               6    Старый клиент
# 3      Жен       33                   1               6    Старый клиент
# 4      Жен       34                   1               6    Старый клиент
# ...    ...      ...                 ...             ...              ...
# 14148  Муж       24                   2               6    Старый клиент
# 14149  Жен       28                   2               6    Старый клиент
# 14150  Муж       27                   1               6    Старый клиент
# 14151  Муж       50                   1               6    Старый клиент
# 14152  Жен       42                   0               6    Старый клиент
#
#        Сумма выдачи номинал  Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
df['Повторный клиент'].unique()
# Out:
# array(['Старый клиент', 'Новый клиент'], dtype=object)

# %%
df['Возраст']
# Out:
# 0        34
# 1        30
# 2        31
# 3        33
# 4        34
#          ..
# 14148    24
# 14149    28
# 14150    27
# 14151    50
# 14152    42
# Name: Возраст, Length: 14153, dtype: int32

# %%
df
# Out:
#        Пол  Возраст  Семейное положение  Национальность Повторный клиент  \
# 0      Муж       34                   1               6    Старый клиент
# 1      Муж       30                   1               6    Старый клиент
# 2      Муж       31                   1               6    Старый клиент
# 3      Жен       33                   1               6    Старый клиент
# 4      Жен       34                   1               6    Старый клиент
# ...    ...      ...                 ...             ...              ...
# 14148  Муж       24                   2               6    Старый клиент
# 14149  Жен       28                   2               6    Старый клиент
# 14150  Муж       27                   1               6    Старый клиент
# 14151  Муж       50                   1               6    Старый клиент
# 14152  Жен       42                   0               6    Старый клиент
#
#        Сумма выдачи номинал  Дата выдачи Дата окончание срока Валюта  Срок  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Повторный клиент'] = le.fit_transform(df['Повторный клиент'])

# %%
df['Повторный клиент'].unique()
# Out:
# array([1, 0])

# %%
df['Пол'] = le.fit_transform(df['Пол'])
df['Пол'].unique()
# Out:
# array([1, 0])

# %%
df = df.drop(columns = ['Дата выдачи'])

# %%
df = df.drop(columns = ['Дата окончание срока'])

# %%
df['Валюта'].unique()
# Out:
# array(['USD', 'TJS', 'RUR'], dtype=object)

# %%
df['Тип залога'].unique()
# Out:
# array(['Смешанное обеспечение', 'Недвижимость', 'Поручительство',
#        'Не обеспеченный', 'Движимое имущество', 'Ювелирные изделия',
#        'Депозит'], dtype=object)

# %%
df['Тип залога'] = le.fit_transform(df['Тип залога'])

# %%
df['Образование'] = le.fit_transform(df['Образование'])

# %%
df['Тип бизнеса'] = le.fit_transform(df['Тип бизнеса'])

# %%
df['Цель кредита'] = le.fit_transform(df['Цель кредита'])

# %%
df['Цель кредита'].unique()
# Out:
# array([1, 2, 4, 5, 7, 0, 3, 6])

# %%
df = df.drop(columns = ['Просрочки за цикл (кумулятивный)'])

# %%
df = df.drop(columns = ['Просрочки на дату 07.06.2021'])

# %%
df = df.drop(columns =  ['Льготный период'])

# %%
df = df.drop(columns = ['Дата списания'])

# %%
df = df.drop(columns = ['Сумма списания'])

# %%
for i in range(0, 14153):
    if df.at[i, 'Валюта'] == 'TJS':
        df.at[i, 'Сумма выдачи номинал'] = df.at[i, 'Сумма выдачи номинал'] / 11
        df.at[i, 'Валюта'] = 'USD'
    if df.at[i, 'Валюта'] == 'RUR':
        df.at[i, 'Сумма выдачи номинал'] = df.at[i, 'Сумма выдачи номинал'] / 97.7
        df.at[i, 'Валюта'] = 'USD'

# %%
df
# Out:
#        Пол  Возраст  Семейное положение  Национальность  Повторный клиент  \
# 0        1       34                   1               6                 1
# 1        1       30                   1               6                 1
# 2        1       31                   1               6                 1
# 3        0       33                   1               6                 1
# 4        0       34                   1               6                 1
# ...    ...      ...                 ...             ...               ...
# 14148    1       24                   2               6                 1
# 14149    0       28                   2               6                 1
# 14150    1       27                   1               6                 1
# 14151    1       50                   1               6                 1
# 14152    0       42                   0               6                 1
#
#        Сумма выдачи номинал Валюта  Срок  Тип залога  Образование  \
# ...

# %%
df = df.drop(columns = ['Валюта'])

# %%
df
# Out:
#        Пол  Возраст  Семейное положение  Национальность  Повторный клиент  \
# 0        1       34                   1               6                 1
# 1        1       30                   1               6                 1
# 2        1       31                   1               6                 1
# 3        0       33                   1               6                 1
# 4        0       34                   1               6                 1
# ...    ...      ...                 ...             ...               ...
# 14148    1       24                   2               6                 1
# 14149    0       28                   2               6                 1
# 14150    1       27                   1               6                 1
# 14151    1       50                   1               6                 1
# 14152    0       42                   0               6                 1
#
#        Сумма выдачи номинал  Срок  Тип залога  Образование  Тип бизнеса  \
# ...

# %%
df.corr().round(2)
# Out:
#                                                      Пол  Возраст  \
# Пол                                                 1.00    -0.18
# Возраст                                            -0.18     1.00
# Семейное положение                                 -0.02    -0.14
# Национальность                                     -0.02     0.08
# Повторный клиент                                   -0.05     0.18
# Сумма выдачи номинал                                0.05     0.03
# Срок                                               -0.05     0.09
# Тип залога                                         -0.01    -0.06
# Образование                                        -0.14     0.11
# Тип бизнеса                                         0.08    -0.08
# Цель кредита                                       -0.08     0.02
# Длительность самой долгой единовременной просро...  0.05    -0.10
#
#                                                     Семейное положение  \
# ...

# %%
df = df.drop(columns = ['Сумма выдачи номинал'])

# %%
df = df.drop(columns = ['Национальность'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10,8))
plot = sns.heatmap(df.corr().round(2), annot = True)
plot.set_title('correlation')
# Out:
# Text(0.5, 1.0, 'correlation')

# %%
for i in range(0,14153):
    if (df.at[i, 'Длительность самой долгой единовременной просрочки в течение цикла'] <= 10):
        df.at[i, 'Длительность самой долгой единовременной просрочки в течение цикла'] = 1
    if (df.at[i, 'Длительность самой долгой единовременной просрочки в течение цикла'] > 10):
        df.at[i, 'Длительность самой долгой единовременной просрочки в течение цикла'] = 0

# %%
df['Длительность самой долгой единовременной просрочки в течение цикла'].unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # TRAIN & TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
df.isnull().sum()
# Out:
# Пол                                                                   0
# Возраст                                                               0
# Семейное положение                                                    0
# Повторный клиент                                                      0
# Срок                                                                  0
# Тип залога                                                            0
# Образование                                                           0
# Тип бизнеса                                                           0
# Цель кредита                                                          0
# Длительность самой долгой единовременной просрочки в течение цикла    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Пол', 'Возраст', 'Семейное положение', 'Повторный клиент', 'Срок',
#        'Тип залога', 'Образование', 'Тип бизнеса', 'Цель кредита',
#        'Длительность самой долгой единовременной просрочки в течение цикла'],
#       dtype='object')

# %%
X = df.drop(columns = 'Длительность самой долгой единовременной просрочки в течение цикла' )

# %%
X
# Out:
#        Пол  Возраст  Семейное положение  Повторный клиент  Срок  Тип залога  \
# 0        1       34                   1                 1    24           5
# 1        1       30                   1                 1    24           5
# 2        1       31                   1                 1    36           5
# 3        0       33                   1                 1    84           5
# 4        0       34                   1                 1    36           5
# ...    ...      ...                 ...               ...   ...         ...
# 14148    1       24                   2                 1    12           4
# 14149    0       28                   2                 1    24           4
# 14150    1       27                   1                 1    18           4
# 14151    1       50                   1                 1    18           2
# 14152    0       42                   0                 1    24           2
#
#        Образование  Тип бизнеса  Цель кредита
# ...

# %%
y = df['Длительность самой долгой единовременной просрочки в течение цикла']
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 21)

# %%
X_train
# Out:
#        Пол  Возраст  Семейное положение  Повторный клиент  Срок  Тип залога  \
# 9684     1       27                   1                 1    18           2
# 10453    1       29                   1                 1    12           4
# 4919     1       49                   1                 1    15           5
# 3915     0       26                   2                 1    12           2
# 11297    0       37                   2                 1    12           2
# ...    ...      ...                 ...               ...   ...         ...
# 9336     1       29                   2                 1    12           4
# 48       1       32                   1                 1    12           2
# 8964     0       45                   4                 0    12           4
# 5944     1       37                   1                 1    18           2
# 5327     1       63                   1                 1     6           1
#
#        Образование  Тип бизнеса  Цель кредита
# ...

# %%
y_test
# Out:
# 8119     0
# 5417     1
# 7338     1
# 10635    1
# 9032     1
#         ..
# 2723     1
# 11645    1
# 13555    1
# 3163     1
# 13414    1
# Name: Длительность самой долгой единовременной просрочки в течение цикла, Length: 4246, dtype: int64

# %%
X_test
# Out:
#        Пол  Возраст  Семейное положение  Повторный клиент  Срок  Тип залога  \
# 8119     0       20                   1                 0    12           4
# 5417     0       28                   2                 0    12           2
# 7338     1       29                   1                 0    12           4
# 10635    1       57                   1                 0    18           2
# 9032     0       57                   1                 1    12           2
# ...    ...      ...                 ...               ...   ...         ...
# 2723     0       52                   3                 1    24           4
# 11645    1       49                   1                 1    18           2
# 13555    1       36                   1                 0    18           2
# 3163     1       34                   1                 0    12           0
# 13414    1       24                   2                 0    12           4
#
#        Образование  Тип бизнеса  Цель кредита
# ...

# %%
df['Цель кредита'].unique()
# Out:
# array([1, 2, 4, 5, 7, 0, 3, 6])

# %% [markdown]
# # LOGREG MODEL

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(random_state=30).fit(X_train, y_train)

# %%
y_pred = logreg.predict(X_test)

# %%
logreg.score(X_train,y_train)
# Out:
# 0.8229534672453821

# %%
logreg.score(X_test, y_test)
# Out:
# 0.8160621761658031

# %% [markdown]
# # Logistic Classifier

# %%
model_logistic = LogisticRegression()
model_logistic.fit(X_train, y_train)
y_pred_logistic = model_logistic.decision_function(X_test)

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC
model_SVC = SVC(kernel ='rbf', random_state = 50)
model_SVC.fit(X_train, y_train)
y_pred_svm = model_SVC.decision_function(X_test)

# %%
from sklearn.metrics import roc_curve, auc

logistic_fpr, logistic_tpr, threshold = roc_curve(y_test, y_pred_logistic)
auc_logistic = auc(logistic_fpr, logistic_tpr)

svm_fpr, svm_tpr, threshold = roc_curve(y_test, y_pred_svm)
auc_svm = auc(svm_fpr, svm_tpr)

logreg_fpr, logreg_tpr, theshold = roc_curve(y_test, y_pred)
auc_logreg = auc(logreg_fpr, logreg_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(svm_fpr, svm_tpr, linestyle='-', label='SVM (auc = %0.3f)' % auc_svm)
plt.plot(logistic_fpr, logistic_tpr, marker='.', label='Logistic (auc = %0.3f)' % auc_logistic)
plt.plot(logreg_fpr, logreg_tpr, linestyle='-', label='Logreg (auc = %0.3f)' % auc_logreg)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix

y_pred = logreg.predict(X_test)  # Replace 'logreg' with your Logistic Regression model
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
conf_matrix
# Out:
# Confusion Matrix:
# array([[   1,  773],
#        [   8, 3464]], dtype=int64)

# %%
from sklearn.metrics import f1_score

y_pred = logreg.predict(X_test)  # Replace 'logreg' with your Logistic Regression model
f1 = f1_score(y_test, y_pred)
print(f'F1-Score: {f1:.2f}')
# Out:
# F1-Score: 0.90

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.82

# %%
from sklearn.metrics import roc_auc_score

# Assuming you have X_test and y_test for testing data
y_pred_logistic = model_logistic.decision_function(X_test)  # Get predicted probabilities for the positive class

# Calculate AUC
auc_score = roc_auc_score(y_test, y_pred_logistic)

print(f'AUC Score: {auc_score:.2f}')
# Out:
# AUC Score: 0.70

# %% [markdown]
# # Random Forest Classifier

# %%
# Import necessary libraries
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Create a Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Train the model on the training data
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the testing data
y_pred = rf_classifier.predict(X_test)

# %%
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
# Print the evaluation results
print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(classification_rep)
# Out:
# Accuracy: 0.79
# Confusion Matrix:
# [[ 121  653]
#  [ 248 3224]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.16      0.21       774
#            1       0.83      0.93      0.88      3472
#
#     accuracy                           0.79      4246
#    macro avg       0.58      0.54      0.54      4246
# weighted avg       0.74      0.79      0.76      4246

# %%
from sklearn.metrics import roc_curve, auc


random_forest_class_fpr,random_forest_class_tpr, theshold = roc_curve(y_test, y_pred)
auc_RandFor = auc(random_forest_class_fpr,random_forest_class_tpr)

plt.figure(figsize=(5, 5), dpi=100)
plt.plot(random_forest_class_fpr,random_forest_class_tpr, marker='.', label='RandFor (auc = %0.3f)' % auc_RandFor)

plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positive Rate -->')

plt.legend()

plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score



# Create a Decision Tree Regressor
dt_regressor = DecisionTreeRegressor(random_state=42)

# Train the model on the training data
dt_regressor.fit(X_train, y_train)

# Make predictions on the testing data
y_pred2 = dt_regressor.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred2)
r2 = r2_score(y_test, y_pred2)

# Print the evaluation results
print(f'Mean Squared Error (MSE): {mse:.2f}')

print(f'R-squared (R2) Score: {r2:.2f}')
# Out:
# Mean Squared Error (MSE): 0.22
# R-squared (R2) Score: -0.50
